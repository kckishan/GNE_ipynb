# %%
f = open('../GNE/march 17', "r")
# use readlines to read all lines in the file
# The variable "lines" is a list containing all lines in the file
lines = f.readlines()
# close the file after reading the lines.
f.close()

# %%
lines
# Out:
# ['/Users/kk3671/anaconda3/bin/python /Users/kk3671/Documents/Gene-Network-Embedding/GNE_runner.py\n',
#  'data_path:  ./data/ecoli/\n',
#  'converting data from ./data/ecoli/\n',
#  'Constructing Nodes\n',
#  'attr_M: 805\n',
#  'id_N: 4511\n',
#  'Constructing Neighborhood maps\n',
#  'Constructing train data\n',
#  'total links: 118672\n',
#  'Constructing test links\n',
#  'test link number: 29668\n',
#  'Constructing validation links\n',
#  'Validation link number: 29668\n',
#  'Constructing all links for testing\n',
#  'Total number of nodes:  4511\n',
#  'Total number of attributes:  805\n',
#  'Total training links:  118672\n',
#  'Total epoch:  20\n',
#  'id_dim : 128\n',
#  'attr_dim : 128\n',
#  "2018-03-15 17:38:37.154139: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.\n",
# ...

# %%
open('results_ecoli.txt','w').writelines([ line.split(":")[1] for line in open('../GNE/march 17') if 'Accuracy' in line])

# %%
f = open('results_ecoli.txt', "r")
# use readlines to read all lines in the file
# The variable "lines" is a list containing all lines in the file
lines = f.readlines()
# close the file after reading the lines.
f.close()

# %%
accuracy = [i.strip().split("  ") for i in lines]

# %%
accuracy
# Out:
# [['0.785193416', '0.801203272'],
#  ['0.784550415', '0.802766308'],
#  ['0.785979495', '0.803165217'],
#  ['0.782566878', '0.801093143'],
#  ['0.782177487', '0.799154489'],
#  ['0.783197874', '0.801673960'],
#  ['0.784405351', '0.800403846'],
#  ['0.783824554', '0.802343928'],
#  ['0.783189576', '0.802334557'],
#  ['0.785715086', '0.803541109'],
#  ['0.816415100', '0.820708499'],
#  ['0.818210905', '0.824350770'],
#  ['0.818308819', '0.823716764'],
#  ['0.815691399', '0.822125838'],
#  ['0.812578920', '0.818707058'],
#  ['0.818026962', '0.824310724'],
#  ['0.816885522', '0.822009524'],
#  ['0.817450331', '0.823782998'],
#  ['0.818426934', '0.824815506'],
#  ['0.816378380', '0.822984895'],
#  ['0.819951313', '0.822232607'],
#  ['0.820847745', '0.825183046'],
#  ['0.820508298', '0.824321684'],
#  ['0.818553276', '0.823380941'],
#  ['0.816796516', '0.820475679'],
#  ['0.820945560', '0.825344157'],
#  ['0.820414555', '0.823486028'],
#  ['0.820535653', '0.824777944'],
# ...

# %%
import numpy as np

# %%
x = [0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1]

# %%
y_ecoli = np.array([0.932, 0.928, 0.922, 0.922, 0.893, 0.866, 0.816, 0.497])

# %%
y_error = np.array([0.002540139535,0.002642020005,0.002294643585,0.002968041767,0.001934542275,0.003718231859])

# %%
y = np.array([0.949, 0.949, 0.944, 0.943,  0.925, 0.907,0.871, 0.816])

# %%
y_error_0 = np.array([0.002260535348, 0.00201944453,0.002152251823,0.001872373902,0.001594262151,0.002253512262])

# %%
import matplotlib.pyplot as plt
from pylab import *
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_ylabel(r"AUROC for interaction prediction", fontsize=12)
# ax.axhline(y=0.839)
ax.set_xlabel("Percentage of interactions for training", fontsize=12)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.plot(x, y, color="r", markersize= 10, marker= "o",linewidth=2, label="Topology + Expression")
ax.plot(x, y_0, color="b", markersize= 10, marker= "^", linewidth=2,  label="Topology")
ax.legend()
plt.savefig('ecoli_results.eps', dpi =1200)
plt.show()

# %%
y_yeast = np.array([0.821, 0.815, 0.808, 0.798, 0.646, 0.638, 0.608, 0.503])

# %%
import matplotlib.pyplot as plt
from pylab import *
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_ylabel(r"AUROC for interaction prediction", fontsize=12)
# ax.axhline(y=0.839)
ax.set_xlabel("Percentage of interactions for training", fontsize=12)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.plot(x, y_ecoli, color="r", markersize= 10, marker= "o",linewidth=2, label="E.coli")
ax.plot(x, y_yeast, color="b", markersize= 10, marker= "^", linewidth=2,  label="Yeast")
ax.legend()
plt.savefig('yeast_ecoli_eccb.png', dpi =1200)
plt.show()

# %%
x = sorted([0,0.2,0.4,0.6,0.8,1])

# %%
x
# Out:
# [0, 0.2, 0.4, 0.6, 0.8, 1]

# %%
y_10 = [0.497388814481, 0.743,0.793173235499, 0.804,0.816, 0.814 ]
y_20 = [0.8065,0.861165579199, 0.865872537851,0.868786408149, 0.871642090879, 0.871598077795, ]
y_30 = [0.866440570079, 0.901634743319, 0.903465150612, 0.906530241462, 0.90777498003, 0.908874511741]
y_40 = [0.893505803015, 0.918747028554,0.922367908151,0.922005091008,0.924738472259,0.926969525971 ]
y_50 = [0.922428357752, 0.933824151173,0.937571442527,0.940377273186,0.942617269283, 0.942664284618]
y_60 = [0.922807514862, 0.936402574002, 0.941037106234, 0.945772280524, 0.944653282459, 0.946627728811]
y_70 = [0.928621536139, 0.941631777114, 0.941174543101, 0.947119486406, 0.948908354139, 0.948352583782]
y_80 = [0.932107273086, 0.942325007325, 0.944620276094, 0.948864184735, 0.949148750266, 0.948235836237]

# %%
import matplotlib.pyplot as plt
from pylab import *
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_ylabel(r"AUROC for interaction prediction", fontsize=12)
# ax.axhline(y=0.839)
ax.set_xlabel("Impact of λ", fontsize=12)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')

ax.plot(x, y_10, color="r", markersize= 7, marker= "o",linewidth=2, label="10% interactions")
# ax.plot(x, y_20, color="b", markersize= 5, marker= "^", linewidth=1,  label="20% interactions")
ax.plot(x, y_30, color="g", markersize= 7, marker= "|",linewidth=2, label="30% interactions")
# ax.plot(x, y_40, color="g", markersize= 5, marker= "^", linewidth=2,  label="40% interactions")
ax.plot(x, y_50, color="k", markersize= 7, marker= "^",linewidth=2, label="50% interactions")
# ax.plot(x, y_60, color="y", markersize= 5, marker= "s", linewidth=1,  label="60% interactions")
# ax.plot(x, y_70, color="k", markersize= 5, marker= "h",linewidth=1, label="70% interactions")
ax.plot(x, y_80, color="b", markersize= 7, marker= "s", linewidth=2,  label="80% interactions")
ax.legend()
plt.savefig('ecoli_sparsity.eps', dpi =1200)
plt.show()
